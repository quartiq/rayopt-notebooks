# %%
import numpy as np
import matplotlib.pyplot as plt

from rayopt import *

np.set_printoptions(precision=3)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s = system_from_yaml("""
description: three lens monochromatic focusing f/1 50mm
stop: 2
wavelengths: [550.0e-9]
object: {angle_deg: 0.01}
elements:
- {material: air, radius: 25}
- {material: SCHOTT/N-BK7, roc: 94.28602, distance: 10, radius: 25}
- {material: air, roc: -392.8918, distance: 8, radius: 25}
- {material: SCHOTT/N-BK7, roc: 43.81682, distance: 6.456843, radius: 23}
- {material: air, roc: 143.1817, distance: 8, radius: 22}
- {material: SCHOTT/N-BK7, roc: 26.17266, distance: 0.1169485, radius: 19}
- {material: air, roc: 33.70628, distance: 5, radius: 18, conic: 0.2594713}
- {material: air, distance: 36.45994, radius: 1}
""")
s.update()
a = Analysis(s, resize=False, refocus_paraxial=False)
# Out:
# /home/rjordens/work/nist/pyrayopt/rayopt/paraxial_trace.py:246: RuntimeWarning: divide by zero encountered in true_divide
#   return self.n.take((0, -2))/(2*na)
# /home/rjordens/work/nist/pyrayopt/rayopt/paraxial_trace.py:251: RuntimeWarning: divide by zero encountered in true_divide
#   return 1.22*self.l/(2*na)/self.system.scale
# /home/rjordens/work/nist/pyrayopt/rayopt/elements.py:208: RuntimeWarning: invalid value encountered in less_equal
#   good = np.square(y[:, :2]).sum(1) <= self.radius**2
# /home/rjordens/work/nist/pyrayopt/rayopt/analysis.py:394: RuntimeWarning: invalid value encountered in true_divide
#   xd = (a[1] - h)/h
# /home/rjordens/work/nist/pyrayopt/rayopt/analysis.py:410: RuntimeWarning: invalid value encountered in true_divide
#   z = -t.y[-1, :, 1]/tanarcsin(t.i[-1])[:, 1]
# /home/rjordens/src/conda/envs/artiq/lib/python3.5/site-packages/matplotlib/collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# System: three lens monochromatic focusing f/1 50mm
# Scale: 1.0 mm
# Wavelengths: 550 nm
# Object:
#  Index: 1
#  Entrance: 50 dia at 10
#  Pupil: 51.5 dia at 15.4
#  Semi-Angle: 0.01
# Image:
#  Index: 1
#  Entrance: 36 dia at 36.5
#  Pupil: 52.6 dia at 51
#  Radius: 0.00873
#  NA: 0.458
# Stop: 2
# Elements:
#  # T   Distance   Rad Curv   Diameter          Material       n      nd      Vd
#  0 S          0        inf         50         basic/air   1.000   1.000   89.30
#  1 S         10      94.29         50      SCHOTT/N-BK7   1.519   1.517   64.17
#  2 S          8     -392.9         50         basic/air   1.000   1.000   89.30
#  3 S     6.4568      43.82         46      SCHOTT/N-BK7   1.519   1.517   64.17
#  4 S          8      143.2         44         basic/air   1.000   1.000   89.30
#  5 S    0.11695      26.17         38      SCHOTT/N-BK7   1.519   1.517   64.17
#  6 S          5      33.71         36         basic/air   1.000   1.000   89.30
#  7 S     36.497        inf   0.017455         basic/air   1.000   1.000   89.30
#
# lagrange: -0.0044947
# track length: 27.574
# object, image height: [ 0.003  0.009]
# petzval radius: 78.098
# front, back focal length (from PP): [-50.041  50.041]
# entry, exit pupil height: [ 25.746  26.277]
# entry, exit pupil distance: [  5.427 -14.577]
# front, back focal distance: [-43.602  36.497]
# front, back principal distance: [  6.439 -13.544]
# front, back nodal distance: [  6.439 -13.544]
# front, back numerical aperture: [ 0.     0.458]
# front, back f number: [ 0.972  0.952]
# front, back working f number: [   inf  1.093]
# front, back airy radius: [   inf  0.001]
# transverse, angular magnification: [-0.    0.98]
#
#  # T     track   axial y   axial u   chief y   chief u
#  0 S         0     25.75         0 -0.002693 0.0001745
#  1 S        10     25.75  -0.09319-0.0009472 0.0001184
#  2 S        18        25   -0.1744         0 0.0001797
#  3 S     24.46     23.87   -0.3009  0.001161 0.0001094
#  4 S     32.46     21.47    -0.379  0.002035 0.0001734
#  5 S     32.57     21.42    -0.529  0.002056  8.74e-05
#  6 S     37.57     18.78   -0.5145  0.002493  0.000171
#  7 S     74.03   0.01908   -0.5145  0.008727  0.000171
#
#  # T       SA3      CMA3      AST3      PTZ3      DIS3
#  0 S         0         0         0        -0         0
#  1 S   -0.1144-6.893e-05-4.153e-08-7.097e-08-6.777e-11
#  2 S   -0.1556 0.0001174-8.867e-08-1.703e-08  7.98e-11
#  3 S  -0.07552-4.204e-05-2.341e-08-1.527e-07-9.806e-11
#  4 S   -0.1979 0.0001621-1.327e-07 4.674e-08 7.038e-11
#  5 S    0.1228 7.041e-05 4.036e-08-2.557e-07-1.234e-10
#  6 S -0.005493-3.159e-05-1.816e-07 1.985e-07 9.713e-11
#  7 S         0        -0         0        -0        -0
#  ∑     -0.4261 0.0002074-4.276e-07-2.511e-07-4.195e-11
# /home/rjordens/src/conda/envs/artiq/lib/python3.5/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
s = system_from_yaml("""
description: uv focusing f/1 50mm (doi:10.1364/AO.31.004397)
stop: 1
wavelengths: [266.0e-9]
object: {angle_deg: 0.1}
elements:
- {material: air}
- {distance: 10, roc: 25.81, material: LITHOSIL-Q, radius: 15.5}
- {distance: 8.595, roc: 18.73, material: air}
- {distance: 8.902, roc: 29.05, material: LITHOSIL-Q}
- {distance: 9.799, roc: -35.88, material: air}
- {distance: 5.659, roc: 13.39, material: LITHOSIL-Q}
- {distance: 4.409, roc: 39.26, material: air} 
- {distance: 1.548, roc: -44.54, material: LITHOSIL-Q}
- {distance: 3.461, roc: 39.26, material: air} 
- {distance: 13.049, material: air}
""")
s.update()
a = Analysis(s, resize_full=True)
# Out:
# /home/rjordens/work/nist/pyrayopt/rayopt/paraxial_trace.py:246: RuntimeWarning: divide by zero encountered in true_divide
#   return self.n.take((0, -2))/(2*na)
# /home/rjordens/work/nist/pyrayopt/rayopt/paraxial_trace.py:251: RuntimeWarning: divide by zero encountered in true_divide
#   return 1.22*self.l/(2*na)/self.system.scale
# /home/rjordens/src/conda/envs/artiq/lib/python3.5/site-packages/numpy/core/function_base.py:107: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /home/rjordens/src/conda/envs/artiq/lib/python3.5/site-packages/numpy/core/function_base.py:112: RuntimeWarning: invalid value encountered in add
#   y += start
# /home/rjordens/work/nist/pyrayopt/rayopt/elements.py:208: RuntimeWarning: invalid value encountered in less_equal
#   good = np.square(y[:, :2]).sum(1) <= self.radius**2
# /home/rjordens/work/nist/pyrayopt/rayopt/analysis.py:394: RuntimeWarning: invalid value encountered in true_divide
#   xd = (a[1] - h)/h
# /home/rjordens/work/nist/pyrayopt/rayopt/analysis.py:410: RuntimeWarning: invalid value encountered in true_divide
#   z = -t.y[-1, :, 1]/tanarcsin(t.i[-1])[:, 1]
# /home/rjordens/src/conda/envs/artiq/lib/python3.5/site-packages/matplotlib/collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# System: uv focusing f/1 50mm (doi:10.1364/AO.31.004397)
# Scale: 1.0 mm
# Wavelengths: 266 nm
# Object:
#  Index: 1
#  Entrance: 31 dia at 10
#  Pupil: 31 dia at 10
#  Semi-Angle: 0.1
# Image:
#  Index: 1
#  Entrance: inf dia at 13
#  Pupil: 59 dia at 59.4
#  Radius: 0.0545
#  NA: 0.445
# Stop: 1
# Elements:
#  # T   Distance   Rad Curv   Diameter          Material       n      nd      Vd
#  0 S          0        inf        inf         basic/air   1.000   1.000   89.30
#  1 S         10      25.81         31 SCHOTT/LITHOSIL-Q   1.500   1.458   67.83
#  2 S      8.595      18.73     26.732         basic/air   1.000   1.000   89.30
#  3 S      8.902      29.05     28.608 SCHOTT/LITHOSIL-Q   1.500   1.458   67.83
#  4 S      9.799     -35.88     28.608         basic/air   1.000   1.000   89.30
#  5 S      5.659      13.39     17.795 SCHOTT/LITHOSIL-Q   1.500   1.458   67.83
#  6 S      4.409      39.26     15.738         basic/air   1.000   1.000   89.30
#  7 S      1.548     -44.54     15.643 SCHOTT/LITHOSIL-Q   1.500   1.458   67.83
#  8 S      3.461      39.26     12.243         basic/air   1.000   1.000   89.30
#  9 S     13.086        inf    0.10904         basic/air   1.000   1.000   89.30
#
# lagrange: -0.027061
# track length: 42.373
# object, image height: [ 0.017  0.054]
# petzval radius: 61.386
# front, back focal length (from PP): [-31.237  31.237]
# entry, exit pupil height: [ 15.5    29.495]
# entry, exit pupil distance: [ -0.    -46.357]
# front, back focal distance: [-16.415  13.084]
# front, back principal distance: [ 14.822 -18.153]
# front, back nodal distance: [ 14.822 -18.153]
# front, back numerical aperture: [ 0.     0.445]
# front, back f number: [ 1.008  0.53 ]
# front, back working f number: [   inf  1.125]
# front, back airy radius: [ inf   0.]
# transverse, angular magnification: [-0.     0.526]
#
#  # T     track   axial y   axial u   chief y   chief u
#  0 S         0      15.5         0  -0.01745  0.001745
#  1 S        10      15.5      -0.2         0  0.001164
#  2 S     18.59     13.78   0.06752   0.01001  0.002012
#  3 S      27.5     14.38   -0.1198   0.02792  0.001022
#  4 S      37.3     13.21   -0.3634   0.03793  0.001005
#  5 S     42.95     11.15   -0.5197   0.04362-0.0004146
#  6 S     47.36      8.86   -0.6665   0.04179-9.027e-05
#  7 S     48.91     7.828    -0.386   0.04165 0.0002512
#  8 S     52.37     6.492   -0.4962   0.04252 0.0009172
#  9 S     65.42   0.01718   -0.4962   0.05449 0.0009172
#
#  # T       SA3      CMA3      AST3      PTZ3      DIS3
#  0 S         0         0         0        -0         0
#  1 S   -0.7509 -0.002182-6.342e-06-9.508e-06-4.607e-08
#  2 S     1.799  0.005703 1.808e-05  1.31e-05 9.883e-08
#  3 S   -0.6759 -0.003572-1.887e-05-8.448e-06-1.444e-07
#  4 S    -2.018-0.0001453-1.047e-08 -6.84e-06-4.933e-10
#  5 S   0.04145 0.0003763 3.417e-06-1.833e-05-1.354e-07
#  6 S   -0.5546  0.001226-2.708e-06 6.251e-06-7.829e-09
#  7 S     2.287  0.002785  3.39e-06  5.51e-06 1.083e-08
#  8 S   -0.1708  0.001033-6.244e-06 6.251e-06-4.204e-11
#  9 S         0        -0         0        -0        -0
#  ∑    -0.04198  0.005223-9.296e-06-1.201e-05-2.245e-07
# /home/rjordens/src/conda/envs/artiq/lib/python3.5/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
